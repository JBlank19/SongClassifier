# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset
dataset = pd.read_parquet("ultraclean_genre_dataset.parquet")

# Display the first few rows of the dataset
dataset.head()
# Out:
#                     name                       artists  explicit  \
# 0                Testify  ['Rage Against The Machine']     False
# 1        Guerrilla Radio  ['Rage Against The Machine']      True
# 2       Calm Like a Bomb  ['Rage Against The Machine']     False
# 3              Mic Check  ['Rage Against The Machine']      True
# 4  Sleep Now In the Fire  ['Rage Against The Machine']     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.470   0.978    7    -5.399     1       0.0727       0.02610
# 1         0.599   0.957   11    -5.764     1       0.1880       0.01290
# 2         0.315   0.970    7    -5.424     1       0.4830       0.02340
# 3         0.440   0.967   11    -5.830     0       0.2370       0.16300
# 4         0.426   0.929    2    -6.729     1       0.0701       0.00162
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000011    0.3560    0.503  117.906       210133             4.0
# 1          0.000071    0.1550    0.489  103.680       206200             4.0
# 2          0.000002    0.1220    0.370  149.749       298893             4.0
# 3          0.000004    0.1210    0.574   96.752       213640             4.0
# 4          0.105000    0.0789    0.539  127.059       205600             4.0
#
#    year                                             genres
# 0  1999  ["alternative metal", "alternative rock", "con...
# 1  1999  ["alternative metal", "alternative rock", "con...
# 2  1999  ["alternative metal", "alternative rock", "con...
# 3  1999  ["alternative metal", "alternative rock", "con...
# 4  1999  ["alternative metal", "alternative rock", "con...

# %%
###### GET ALL GENRES LIST IN DATASET ######

import pandas as pd
import ast  # for safely evaluating strings as Python literals

# Load the dataset
# dataset = pd.read_parquet("SongClassifier/ultraclean_genre_dataset.parquet")

def safe_literal_eval(val):
    try:
        return ast.literal_eval(val)
    except ValueError:
        return []  # or some other default like ['Unknown']

# Convert the string representation of lists back to lists
dataset['genres'] = dataset['genres'].apply(safe_literal_eval)

# Extract and flatten the list of genres
all_genres = [genre for sublist in dataset['genres'] for genre in sublist]

# Get distinct genres
distinct_genres = set(all_genres)

# Convert the set back to a list if you need it as a list
distinct_genres_list = list(distinct_genres)

# Print or inspect the distinct genres
print(distinct_genres_list)
print(len(distinct_genres_list))
# Out:
# ['birmingham metal', 'post-hardcore', 'instrumental math rock', 'ai', 'guitarra clasica', 'spanish modern rock', 'deconstructed club', 'afrofuturismo brasileiro', 'british singer-songwriter', 'fluxwork', 'musique traditionnelle congolaise', 'reggae catala', 'british folk', 'indonesian worship', 'utah metal', 'rap montrealais', 'indie game soundtrack', 'tamborazo', 'vintage chanson', 'gangster rap', 'ukrainian classical', 'cuban rumba', 'black thrash', 'modern free jazz', 'pop rock brasileiro', 'psytech', 'nyhc', 'czsk black metal', 'classical flute', 'turkish post-punk', 'danish hip hop', 'tibetan traditional', 'drill and bass', 'chillwave', 'belarusian metal', 'bolero mexicano', 'turkish psych', 'guatemalan metal', 'brazilian ccm', 'korean underground rap', 'ebm', 'pibroch', 'nasyid', 'batidao romantico', 'barnemusikk', 'soul jazz', 'hip hop galsen', 'c64', 'musica indigena brasileira', 'australian post-rock', 'freakbeat', 'kosovan pop', 'caucasian classical', 'nordic folk', 'rap metal espanol', 'modern cello', 'new orleans jazz', 'aussie emo', 'classic colombian pop', 'gaian doom', 'christian hip hop', 'german hardcore', 'portuguese folk', 'modern jazz piano', 'mexican classic rock', 'swedish tropical house', 'uruguayan indie', 'rap mineiro', 'chanson', 'chinese folk', 'kizomba', 'dutch dnb', 'british death metal', 'serbian electronic', 'scottish new wave', 'vapor pop', 'electro bailando', 'atmospheric post-rock', 'string quartet', 'french pop', 'ottawa indie', 'nz reggae', 'hindustani instrumental', 'vocal ensemble', 'swedish indie pop', 'folk rock italiano', 'azeri traditional', 'irish pub song', 'danish singer-songwriter', 'reggae rock', 'newcastle indie', 'new england emo', 'karaoke', 'russian gangster rap', 'canadian indigenous hip hop', 'pop argentino', 'derry indie', 'ninja', 'latin worship', 'jazz brass', 'heavy alternative', 'turkish pop', 'kayokyoku', 'new americana', 'nederpop', 'wisconsin metal', 'metal', 'zouk', 'japanese alternative rock', 'classical organ', 'arab alternative', 'neo-proto', 'icelandic electronic', 'drumfunk', 'chamame brasilero', 'rock of gibraltar', 'nu metal', 'rochester mn indie', 'indy indie', 'canadian folk', 'vaporwave', 'reggae tuga', 'romanian metal', 'baglama', 'ghazal', 'glitch hop', 'partyschlager', 'chinese punk', 'gospel italiano', 'latvian metal', 'post-punk mexicano', 'indie quebecois', 'mariachi', 'cumbia santafesina', 'modern salsa', 'ambient techno', 'vapor soul', 'cuatro venezolano', 'latin american classical piano', 'adoracao', 'harmonica blues', 'microhouse', 'liedermacher', 'bolero', 'classic dubstep', 'italian power metal', 'new weird america', 'post-metal', 'deep jazz fusion', 'chinese indie', 'grim death metal', 'malian blues', 'rock curitibano', 'hungarian folk', "muzika l'yeladim", 'argentine telepop', 'rhythm and boogie', 'folclore extremeno', 'bemani', 'auteur-compositeur-interprete quebecois', 'electronic djent', 'bossa nova jazz', 'nz pop', 'russian hardcore', 'rumba catalana', 'twin cities indie', 'north carolina indie', 'peruvian indie', 'scorecore', 'christian deathcore', 'avant-garde black metal', 'jewish pop', 'nashville singer-songwriter', 'brazilian surf rock', 'austrian choir', 'psychedelic jazz fusion', 'newfoundland indie', 'tuareg guitar', 'schlager', 'cumbia', 'czech rock', 'family gospel', 'piano cover', 'classical horn', 'fremantle indie', 'korean contemporary classical', 'german trap', 'adventista', 'finnish indie', 'punk euskera', 'latin christian', 'vintage rockabilly', 'musica santomense', 'brazilian house', 'free jazz', 'chutney', 'new wave of thrash metal', 'qawwali', 'bachata', 'bass house', 'rock nacional brasileiro', 'russian alternative rock', 'musica campineira', 'new orleans americana', 'weightless', 'punta', 'south african jazz', 'latin arena pop', 'chaabi algerien', 'contemporary post-bop', 'japanese psychedelic rock', 'cincinnati indie', 'lo-fi brasileiro', 'choro contemporaneo', 'new wave of osdm', 'french reggae', 'italian modern pro ...
# 4649

# %%
def reclassify_genre(genre_list):
    super_genres = []
    unclassified_genres = []

    # Define keywords for each super genre
    genre_keywords = {
    'Industrial/Gothic': ['industrial', 'gothic', 'dark wave', 'neue deutsche härte', 'ethereal wave'],
    'Metal': ['metal', 'grindcore', "black 'n' roll", 'ukhc', 'deathcore', 'djent', 'black metal', 'doom metal'],
    'Rock/Indie': ['rock', 'indie', 'punk', 'guitar', 'screamo', 'post-romantic', 'hard rock', 'garage rock', 'psychedelic rock', 'folk rock', 'alternative rock', 'post-rock', 'shoegaze'],
    'Pop': ['pop', 'synthpop', 'electropop', 'pop rock', 'pop punk', 'k-pop', 'j-pop'],
    'Country': ['country', 'deathgrass', 'nashville sound', 'americana', 'bluegrass', 'country rock', 'outlaw country', 'tex-mex'],
    'Blues/Jazz': ['blues', 'jazz', 'r&b', 'rhythm and blues', 'soul', 'funk', 'swing', 'bebop', 'hard bop', 'cool jazz', 'jazz fusion'],
    'Reggae': ['reggae', 'ska', 'dancehall', 'dub', 'ragga'],
    'Rap/Hiphop': ['rap', 'hiphop', 'hip-hop', 'hip hop', 'hop', 'trap', 'gangsta rap', 'east coast hip hop', 'west coast hip hop', 'southern hip hop'],
    'EDM': ['edm', 'electronic', 'dance music', 'electro', 'house', 'techno', 'trance', 'drum and bass', 'dubstep', 'big room', 'deep house', 'progressive house', 'tech house', 'electro house'],
    'Urban/Reggaeton': ['urban', 'reggaeton', 'latin trap', 'bachata', 'merengue'],
    'Classical': ['classical', 'orchestra', 'baroque', 'romantic era', 'serialism', 'chamber music', 'opera', 'symphonic'],
    'Folk/Traditional': ['folk', 'traditional', 'tradicional', 'brega', 'copla', 'bagpipe', 'celtic', 'chanson', 'world music', 'ethnic', 'native american', 'andalusian classical', 'medieval'],
    'Miscellaneous': []
}

    # Check each genre in the list against the keywords
    for genre in genre_list:
        classified = False
        for super_genre, keywords in genre_keywords.items():
            if any(keyword in genre.lower() for keyword in keywords):
                super_genres.append(super_genre)
                classified = True
                break
        if not classified:
            super_genres.append('Miscellaneous')

    # Combine super genres and unclassified genres
    return super_genres

# Apply the function to the dataset
dataset['super_genres'] = dataset['genres'].apply(reclassify_genre)

# Optionally, display the updated dataset
dataset.sample(n=5)
# Out:
#                                          name  \
# 610597                              Sacrifice
# 467187                             Doin' Well
# 624422                                  Honey
# 299630  24 Preludes, Op. 28: No. 9 in E Major
# 144559                        I'm Coming Home
#
#                                                   artists  explicit  \
# 610597                                        ['G Herbo']      True
# 467187  ['Buddah Tai', 'Yukmouth', 'TREECHOPPA', 'Slee...      True
# 624422                                 ['Sudan Archives']      True
# 299630               ['Frédéric Chopin', 'Beatrice Rana']     False
# 144559                                    ['Lisa Hilton']     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 610597         0.687  0.6110    0    -7.037     1       0.2420        0.0144
# 467187         0.699  0.7060    8    -4.831     1       0.1450        0.1640
# 624422         0.551  0.8060    9    -6.614     0       0.0696        0.0140
# 299630         0.422  0.0342    4   -24.531     1       0.0623        0.9950
# 144559         0.254  0.1720    9   -16.260     0       0.0300        0.9310
#
#         instrumentalness  liveness  valence    tempo  duration_ms  \
# 610597          0.000004     0.764   0.3570  163.003       214947
# 467187          0.000000     0.086   0.5640   84.999       328371
# 624422          0.202000     0.374   0.2470  120.042       182749
# 299630          0.930000     0.101   0.0372   75.444       101493
# 144559          0.799000     0.103   0.1230   71.314       208120
#
#         time_signature  year  \
# 610597             4.0  2019
# 467187             4.0  2016
# 624422             4.0  2019
# 299630             4.0  2012
# 144559             4.0  2002
#
#                                                    genres  \
# 610597  [chicago drill, chicago rap, drill, rap, south...
# 467187  [hyphy, oakland hip hop, west coast rap, west ...
# 624422  [afrofuturism, alternative r&b, escape room, e...
# 299630  [classical, early romantic era, polish classic...
# 144559                                [modern jazz piano]
#
#                                              super_genres
# 610597  [Miscellaneous, Rap/Hiphop, Miscellaneous, Rap...
# 467187  [Miscellaneous, Rap/Hiphop, Rap/Hiphop, Rap/Hi...
# 624422  [Miscellaneous, Blues/Jazz, Miscellaneous, Blu...
# 299630  [Classical, Classical, Classical, Classical, C...
# 144559                                       [Blues/Jazz]

# %%
# Extracting distinct genres from the 'genre' column
distinct_genres = set()
for genres in dataset['super_genres']:
    distinct_genres.update(genres)

distinct_genres_list = list(distinct_genres)
#distinct_genres_list.sort()

print(len(distinct_genres_list))
print(distinct_genres_list)
# Out:
# 13
# ['Urban/Reggaeton', 'Rap/Hiphop', 'Pop', 'Blues/Jazz', 'Classical', 'Rock/Indie', 'EDM', 'Miscellaneous', 'Country', 'Metal', 'Folk/Traditional', 'Industrial/Gothic', 'Reggae']

# %%
# Mapping of super genres to their assigned numbers
genre_number_mapping = {
    'Industrial/Gothic': 0,
    'EDM': 1,
    'Reggae': 2,
    'Metal': 3,
    'Blues/Jazz': 4,
    'Country': 5,
    'Urban/Reggaeton': 6,
    'Rap/Hiphop': 7,
    'Rock/Indie': 8,
    'Pop': 9,
    'Classical': 10,
    'Folk/Traditional': 11,
    'Miscellaneous': 12
}

# Assuming df is your DataFrame and 'super_genres' is the column with genres
def assign_genre_number(row):
    genres = row['super_genres']  # Adjust splitting logic based on your data format
    if len(genres) == 1:
        return genre_number_mapping[genres[0]]
    else:
        # Using the main genre method
        return min(genre_number_mapping[genre] for genre in genres)

dataset['super_genre'] = dataset.apply(assign_genre_number, axis=1)

dataset.sample(n=5)
# Out:
#                                    name                            artists  \
# 293350              My Heart’s Own Love                  ['Red Tail Ring']
# 42484                            Muzzle                     ['The Gasman']
# 790968           Don't Stop - Live 1977                  ['Fleetwood Mac']
# 412511                       Summertime  ['Eric Alexander', 'Pat Martino']
# 384597  Cheeseburger in Paradise - Live                  ['Jimmy Buffett']
#
#         explicit  danceability  energy  key  loudness  mode  speechiness  \
# 293350     False         0.645   0.307    7   -10.270     1       0.0274
# 42484      False         0.789   0.468    5   -15.097     1       0.0670
# 790968     False         0.437   0.842    9    -7.802     1       0.0732
# 412511     False         0.421   0.560    0    -9.146     0       0.0340
# 384597     False         0.579   0.928    2    -5.021     1       0.0978
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 293350        0.9230          0.000052    0.1080    0.398   98.315
# 42484         0.0295          0.819000    0.1540    0.231  146.296
# 790968        0.1570          0.000000    0.9330    0.658  125.065
# 412511        0.6600          0.052500    0.0858    0.802  117.033
# 384597        0.3700          0.000000    0.6920    0.801  134.778
#
#         duration_ms  time_signature  year  \
# 293350       201227             4.0  2013
# 42484        201600             4.0  2005
# 790968       231653             4.0  1977
# 412511       404680             3.0  2015
# 384597       212840             4.0  2003
#
#                                                    genres  \
# 293350        [michigan indie, modern old-time, old-time]
# 42484                          [deep idm, drill and bass]
# 790968  [album rock, classic rock, mellow gold, rock, ...
# 412511  [hard bop, jazz saxophone, straight-ahead jazz...
# 384597                [folk rock, mellow gold, soft rock]
#
#                                              super_genres  super_genre
# 293350         [Rock/Indie, Miscellaneous, Miscellaneous]            8
# 42484                      [Miscellaneous, Miscellaneous]           12
# 790968  [Rock/Indie, Rock/Indie, Miscellaneous, Rock/I...            8
# 412511  [Blues/Jazz, Blues/Jazz, Blues/Jazz, Blues/Jaz...            4
# 384597            [Rock/Indie, Miscellaneous, Rock/Indie]            8

# %%
dataset = dataset.drop(columns=['genres', 'super_genres'])

dataset.sample(n=5)
# Out:
#                                                      name  \
# 753683  Prelude and Fugue in D Minor, Op. 98: Fugue: A...
# 174942                                Did We Have A Party
# 114659                                            Emanuel
# 89763                                      Just a Machine
# 544698                                       A Linda Song
#
#                                      artists  explicit  danceability  energy  \
# 753683  ['Alexander Glazunov', 'Iain Quinn']     False         0.173   0.115
# 174942                       ['Billy Brown']     False         0.313   0.819
# 114659            ['Michael Allen Harrison']     False         0.236   0.219
# 89763                            ['Eurotix']     False         0.577   0.667
# 544698                     ['Barry Manilow']     False         0.338   0.273
#
#         key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 753683    2   -23.664     0       0.0401       0.70900            0.7140
# 174942    2    -5.488     0       0.0688       0.87800            0.0000
# 114659    4   -19.100     0       0.0369       0.81100            0.9710
# 89763     9   -10.881     1       0.0307       0.00135            0.0119
# 544698    0   -11.066     1       0.0310       0.74100            0.0000
#
#         liveness  valence    tempo  duration_ms  time_signature  year  \
# 753683    0.0849   0.0498  119.924       342720             3.0  2003
# 174942    0.1230   0.9090  155.603       147067             4.0  1956
# 114659    0.1050   0.0682  127.849       440387             3.0  1998
# 89763     0.4200   0.1220  101.977       410827             4.0  2019
# 544698    0.1830   0.1320  122.044       200467             4.0  1978
#
#         super_genre
# 753683            8
# 174942            8
# 114659           12
# 89763             9
# 544698            8

# %%
dataset.to_parquet('ultraclean_super_genre_dataset.parquet')
